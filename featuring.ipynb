# %% [markdown]
# We will first encode categorical values into a numerical one: Credit Score Category, Gender, AgeGroup, Geography. And we will also normalise Balance and Estimated Salary.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Bank_Churn.csv")
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0          0.00              1          1               1        101348.88
# 1      83807.86              1          0               1        112542.58
# 2     159660.80              3          1               0        113931.57
# 3          0.00              2          0               0         93826.63
# 4     125510.82              1          1               1         79084.10
# ...         ...            ...        ...             ...              ...
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0
#
# [10000 rows x 13 columns]

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[18, 25, 35, 45, 60,100], labels=['18-25', '26-35', '36-45', '46-60', '60+'])
df['CreditScoreCat'] = pd.cut(df['CreditScore'], 
                                   bins=[300, 580, 669, 739, 799, 850], 
                                   labels=['Poor', 'Fair', 'Good', 'Very Good', 'Exceptional'])

# %%
new_df = df.drop(columns = ['CustomerId','Surname','CreditScore','Age'])
new_df
# Out:
#      Geography  Gender  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0       France  Female       2       0.00              1          1
# 1        Spain  Female       1   83807.86              1          0
# 2       France  Female       8  159660.80              3          1
# 3       France  Female       1       0.00              2          0
# 4        Spain  Female       2  125510.82              1          1
# ...        ...     ...     ...        ...            ...        ...
# 9995    France    Male       5       0.00              2          1
# 9996    France    Male      10   57369.61              1          1
# 9997    France  Female       7       0.00              1          0
# 9998   Germany    Male       3   75075.31              2          1
# 9999    France  Female       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited AgeGroup CreditScoreCat
# 0                  1        101348.88       1    36-45           Fair
# 1                  1        112542.58       0    36-45           Fair
# 2                  0        113931.57       1    36-45           Poor
# 3                  0         93826.63       0    36-45           Good
# 4                  1         79084.10       0    36-45    Exceptional
# ...              ...              ...     ...      ...            ...
# 9995               0         96270.64       0    36-45      Very Good
# 9996               1        101699.77       0    26-35           Poor
# 9997               1         42085.58       1    36-45           Good
# 9998               0         92888.52       1    36-45      Very Good
# 9999               0         38190.78       0    26-35      Very Good
#
# [10000 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(new_df.drop(columns=['Exited']) ,new_df['Exited'],test_size = 0.3, random_state = 0)
X_train.shape, X_test.shape
# Out:
# 7681    1
# 9031    0
# 3691    0
# 202     1
# 5625    0
#        ..
# 9225    0
# 4859    0
# 3264    0
# 9845    0
# 2732    1
# Name: Exited, Length: 7000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1',StandardScaler(),['Balance','EstimatedSalary']),
    ('tnf2',OrdinalEncoder(categories=[['Poor', 'Fair', 'Good', 'Very Good', 'Exceptional']]),['CreditScoreCat']),
    ('tnf3',OrdinalEncoder(categories=[['18-25', '26-35', '36-45', '46-60', '60+']]),['AgeGroup']),
    ('tnf4',OneHotEncoder(sparse_output = False, drop = 'first'),['Gender','Geography'])
],remainder = 'passthrough')

# %%
transformer.fit_transform(X_train)

# %% [markdown]
# This is my first time using a Column Transformer. I can't figure out why the transfrom fit is throwing an error of Nan values when there are not. I will identify it soon and update here.
